# %%
import h5py


H5_PATH = "../outputs/predictor/predictor_compilation_gate_time_1_to_1-batch009.h5"

with h5py.File(H5_PATH, "r") as f:
    results = f.get("results")
    if results is None:
        raise ValueError("No 'results' group found in H5 file")

    run_names = list(results.keys())
    print(f"Runs: {len(run_names)}")
    for run_name in run_names[:5]:
        attrs = dict(results[run_name].attrs)
        print(run_name, attrs)
# Out:
# Runs: 1552
# run_0000 {'algorithm_name': 'VQC_circuit_reupload-False_qubits-10_layers-2_gate-X_ansatz-circuit_4_INDEP-False_quantinuum_h2_56_L1_best', 'circuit_name': 'VQC_circuit_reupload-False_qubits-10_layers-2_gate-X_ansatz-circuit_4_INDEP-False_quantinuum_h2_56_L1_best', 'cost_after': np.float64(nan), 'cost_before': np.float64(nan), 'cpu_time_seconds': np.float64(0.88643), 'final_timesteps': np.int64(258), 'gate_count': np.int64(110), 'gate_time_one_qubit': 'None', 'gate_time_two_qubit': np.int64(1), 'idle_count': np.int64(2470), 'move_distance_total': np.float64(nan), 'num_ions': np.int64(10), 'qasm_file': 'inputs/qasm_files/quantinuum-compiled-circuits/qasm_be_split/batch_009/VQC_circuit_reupload-False_qubits-10_layers-2_gate-X_ansatz-circuit_4_INDEP-False_quantinuum_h2_56_L1_best.qasm', 'success': np.True_, 'timesteps_lower_bound': np.int64(36)}
# run_0001 {'algorithm_name': 'VQC_circuit_reupload-False_qubits-10_layers-2_gate-Y_ansatz-circuit_18_INDEP-False_quantinuum_h2_56_L2_best', 'circuit_name': 'VQC_circuit_reupload-False_qubits-10_layers-2_gate-Y_ansatz-circuit_18_INDEP-False_quantinuum_h2_56_L2_best', 'cost_after': np.float64(nan), 'cost_before': np.float64(nan), 'cpu_time_seconds': np.float64(0.670453), 'final_timesteps': np.int64(178), 'gate_count': np.int64(69), 'gate_time_one_qubit': 'None', 'gate_time_two_qubit': np.int64(1), 'idle_count': np.int64(1711), 'move_distance_total': np.float64(nan), 'num_ions': np.int64(10), 'qasm_file': 'inputs/qasm_files/quantinuum-compiled-circuits/qasm_be_split/batch_009/VQC_circuit_reupload-False_qubits-10_layers-2_gate-Y_ansatz-circuit_18_INDEP-False_quantinuum_h2_56_L2_best.qasm', 'success': np.True_, 'timesteps_lower_bound': np.int64(26)}
# run_0002 {'algorithm_name': 'VQC_circuit_reupload-False_qubits-10_layers-3_gate-X_ansatz-circuit_10_INDEP-False_quantinuum_h2_56_L1_best', 'circuit_name': 'VQC_circuit_reupload-False_qubits-10_layers-3_gate-X_ansatz-circuit_10_INDEP-False_quantinuum_h2_56_L1_best', 'cost_after': np.float64(nan), 'cost_before': np.float64(nan), 'cpu_time_seconds': np.float64(1.250858), 'final_timesteps': np.int64(283), 'gate_count': np.int64(130), 'gate_time_one_qubit': 'None', 'gate_time_two_qubit': np.int64(1), 'idle_count': np.int64(2700), 'move_distance_total': np.float64(nan), 'num_ions': np.int64(10), 'qasm_file': 'inputs/qasm_files/quantinuum-compiled-circuits/qasm_be_split/batch_009/VQC_circuit_reupload-False_qubits-10_layers-3_gate-X_ansatz-circuit_10_INDEP-False_quantinuum_h2_56_L1_best.qasm', 'success': np.True_, 'timesteps_lower_bound': np.int64(47)}
# run_0003 {'algorithm_name': 'VQC_circuit_reupload-False_qubits-10_layers-3_gate-X_ansatz-circuit_6_INDEP-False_quantinuum_h2_56_L2_best', 'circuit_name': 'VQC_circuit_reupload-False_qubits-10_layers-3_gate-X_ansatz-circuit_6_INDEP-False_quantinuum_h2_56_L2_best', 'cost_after': np.float64(nan), 'cost_before': np.float64(nan), 'cpu_time_seconds': np.float64(11.698139), 'final_timesteps': np.int64(2507), 'gate_count': np.int64(702), 'gate_time_one_qubit': 'None', 'gate_time_two_qubit': np.int64(1), 'idle_count': np.int64(24368), 'move_distance_total': np.float64(nan), 'num_ions': np.int64(10), 'qasm_file': 'inputs/qasm_files/quantinuum-compiled-circuits/qasm_be_split/batch_009/VQC_circuit_reupload-False_qubits-10_layers-3_gate-X_ansatz-circuit_6_INDEP-False_quantinuum_h2_56_L2_best.qasm', 'success': np.True_, 'timesteps_lower_bound': np.int64(310)}
# run_0004 {'algorithm_name': 'VQC_circuit_reupload-False_qubits-10_layers-3_gate-Y_ansatz-circuit_2_INDEP-False_quantinuum_h2_56_L1_best', 'circuit_name': 'VQC_circuit_reupload-False_qubits-10_layers-3_gate-Y_ansatz-circuit_2_INDEP-False_quantinuum_h2_56_L1_best', 'cost_after': np.float64(nan), 'cost_before': np.float64(nan), 'cpu_time_seconds': np.float64(1.107337), 'final_timesteps': np.int64(308), 'gate_count': np.int64(156), 'gate_time_one_qubit': 'None', 'gate_time_two_qubit': np.int64(1), 'idle_count': np.int64(2924), 'move_distance_total': np.float64(nan), 'num_ions': np.int64(10), 'qasm_file': 'inputs/qasm_files/quantinuum-compiled-circuits/qasm_be_split/batch_009/VQC_circuit_reupload-False_qubits-10_layers-3_gate-Y_ansatz-circuit_2_INDEP-False_quantinuum_h2_56_L1_best.qasm', 'success': np.True_, 'timesteps_lower_bound': np.int64(52)}

# %%
import csv
import h5py

CSV_PATH = H5_PATH.replace(".h5", ".csv")

columns = [
    "circuit_name",
    "num_ions",
    "gate_count",
    "success",
    "final_timesteps",
    "cpu_time_seconds",
    "idle_count",
    "gate_time_one_qubit",
    "gate_time_two_qubit",
    "num_pzs",
    "max_ions_per_pz",
    "arch",
]

with h5py.File(H5_PATH, "r") as f:
    results = f.get("results")
    if results is None:
        raise ValueError("No 'results' group found in H5 file")

    with open(CSV_PATH, "w", newline="", encoding="utf-8") as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=columns)
        writer.writeheader()
        for run_name in results.keys():
            attrs = results[run_name].attrs
            row = {key: attrs.get(key) for key in columns}
            writer.writerow(row)

print(f"Wrote {CSV_PATH}")
# Out:
# Wrote ../outputs/predictor/predictor_compilation_gate_time_1_to_1-batch009.csv
